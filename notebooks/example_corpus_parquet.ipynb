# %%
from archive_query_log import DATA_DIRECTORY_PATH

example_dir = DATA_DIRECTORY_PATH / "examples"
example_serps_path_json = example_dir / "serps.jsonl"
example_serps_dir = example_dir / "serps"
example_serps_dir_parquet = example_serps_dir / "parquet"
example_serps_dir_jsonl = example_serps_dir / "jsonl"
example_serps_dir_csv = example_serps_dir / "csv"
example_results_path_json = example_dir / "results.jsonl"
example_results_dir = example_dir / "results"
example_results_dir_parquet = example_results_dir / "parquet"
example_results_dir_jsonl = example_results_dir / "jsonl"
example_results_dir_csv = example_results_dir / "csv"

# %%
from archive_query_log.config import SERVICES
from datetime import datetime
from publicsuffixlist import PublicSuffixList
from urllib.parse import urlparse

public_suffix_list = PublicSuffixList()


def domain(url):
    return urlparse(url).hostname


def public_suffix(url):
    return public_suffix_list.publicsuffix(domain(url))


def year(timestamp):
    return datetime.fromtimestamp(timestamp).year


def month(timestamp):
    return datetime.fromtimestamp(timestamp).month


def search_provider(name):
    service = SERVICES[name]
    return {
        "name": name,
        "alexa_domain": service.alexa_domain,
        "alexa_public_suffix": service.public_suffix,
        "alexa_rank": service.alexa_rank,
        "category": service.category,
    }

# %%
from json import loads

with example_serps_path_json.open("rt") as example_serps_file:
    example_serps = [loads(line) for line in example_serps_file]

# %%
from pyarrow import table
from archive_query_log.schema import SERP_SCHEMA

serps_table = table(
    data={
        "serp_id": [query["id"] for query in example_serps],
        "serp_url": [query["url"] for query in example_serps],
        "serp_domain": [domain(query["url"]) for query in example_serps],
        "serp_domain_public_suffix": [public_suffix(query["url"]) for query in example_serps],
        "serp_timestamp": [query["timestamp"] for query in example_serps],
        "serp_year": [year(query["timestamp"]) for query in example_serps],
        "serp_month": [month(query["timestamp"]) for query in example_serps],
        "serp_wayback_url": [query["wayback_url"] for query in example_serps],
        "serp_wayback_raw_url": [query["wayback_raw_url"] for query in example_serps],
        "serp_page": [query["url_page"] for query in example_serps],
        "serp_offset": [query["url_offset"] for query in example_serps],
        "serp_query_text_url": [query["url_query"] for query in example_serps],
        "serp_query_text_url_language": [query["language"] for query in example_serps],
        "serp_query_text_html": [query["serp_query"] for query in example_serps],
        "serp_warc_relative_path": [query["archived_raw_serp_location"]["relative_path"] for query in example_serps],
        "serp_warc_byte_offset": [query["archived_raw_serp_location"]["byte_offset"] for query in example_serps],
        "serp_results": [
            [
                {
                    "result_id": result["id"],
                    "result_url": result["url"],
                    "result_domain": domain(result["url"]),
                    "result_domain_public_suffix": public_suffix(result["url"]),
                    "result_wayback_url": result["wayback_url"],
                    "result_wayback_raw_url": result["wayback_raw_url"],
                    "result_snippet_rank": result["snippet_rank"],
                    "result_snippet_title": result["snippet_title"],
                    "result_snippet_text": result["snippet_text"],
                    "result_warc_relative_path": None,
                    "result_warc_byte_offset": None,
                }
                for result in query["results"]
            ]
            for query in example_serps
        ],
        "search_provider_name": [query["service"] for query in example_serps],
        "search_provider_alexa_domain": [search_provider(query["service"])["alexa_domain"] for query in example_serps],
        "search_provider_alexa_domain_public_suffix":
            [search_provider(query["service"])["alexa_public_suffix"] for query in example_serps],
        "search_provider_alexa_rank": [search_provider(query["service"])["alexa_rank"] for query in example_serps],
        "search_provider_category": [search_provider(query["service"])["category"] for query in example_serps],
    },
    schema=SERP_SCHEMA,
)

# %%
from shutil import rmtree, make_archive
from archive_query_log.schema import SERP_PARTITIONING
from pyarrow.parquet import write_to_dataset
from pandas import read_parquet

if example_serps_dir.exists():
    rmtree(example_serps_dir)
example_serps_dir.mkdir()
write_to_dataset(
    serps_table,
    root_path=example_serps_dir_parquet,
    partitioning=SERP_PARTITIONING,
    basename_template="serps_{i}.parquet",
)
for path in example_serps_dir_parquet.rglob("**/*.parquet"):
    df = read_parquet(path)
    rel_path = path.relative_to(example_serps_dir_parquet)
    csv_path = (example_serps_dir_csv / rel_path).with_suffix(".csv")
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(csv_path, index=False)
    jsonl_path = (example_serps_dir_jsonl / rel_path).with_suffix(".json")
    jsonl_path.parent.mkdir(parents=True, exist_ok=True)
    df.to_json(jsonl_path, orient="records", lines=True)
make_archive(example_serps_dir, "zip", example_serps_dir)
# Out:
# '/home/heinrich/Repositories/archive-query-log/data/examples/serps.zip'

# %%
read_parquet(example_serps_dir_parquet)
# Out:
#                                  serp_id  \
# 0   3d8b4173-1cc6-5f4b-8ed3-30f10e439a42
# 1   1149f047-d43c-5e67-a34f-55614c2cc3ba
# 2   b32f13d4-aa25-5ff5-b338-c9e3df466cb4
# 3   c027789e-30d9-5532-a6b9-bd1b73300ac9
# 4   8d6e45fb-bd0c-514d-890d-55802b52550a
# 5   afbb1256-ffa0-5ba4-a450-6a89aa2f3f59
# 6   56cbbee2-9915-58d9-9141-a5690428f7e7
# 7   c7d12165-1b24-5644-a95a-2af066e18996
# 8   80d05846-77cb-5892-8570-cf28567c975d
# 9   d7899daf-8fee-51b1-a1e6-25a4c5995f67
# 10  a76da3e8-46ea-5753-aa93-cffdb659a521
# 11  d16de9a9-db9c-584e-87e1-868a3d983730
# 12  0fe98c44-e041-5e8b-a4b4-a356f3aa8d79
# 13  b4933227-7995-527f-9943-95de6d2278fb
# 14  cf92e831-400c-59cd-a4f0-a68479182048
# 15  ff64a918-2445-57c9-b659-43879c17f8fd
# 16  47fcc917-e751-55ce-9f43-b5dfac9b7a5d
# 17  dc67889e-c955-5e81-8a7d-c150246bb6fa
# 18  4b85d6d1-2b64-5a97-bf20-b7bf63d5691f
# 19  70925025-6801-5d44-92ed-1bd9dcb9affa
# 20  c33b15d6-d0ee-5861-810c-2f88d6b16ef8
# 21  98f58909-5b3b-5013-838f-0205bf080a37
# 22  34c2456c-1759-59e5-a678-10a1fa827fd7
# 23  0e463c96-8d65-589f-ba78-e8a444e8f843
# 24  22e0246c-48c0-564d-a20a-f41ddd839e4d
# 25  221cbfac-4b93-5487-9340-33e014fe8fd8
# 26  b8b39418-ddf0-58c8-9fec-b46cde2083cb
# 27  fbd8aae1-44b9-5ea6-a8c9-3042aa96b921
# 28  01c0ae1c-041d-530e-a15e-842199041009
# 29  8bf699d9-5d05-589d-a1b2-8654c3fd9757
# 17  https://web.archive.org/web/20130613094617/htt...
# 18  https://web.archive.org/web/20141007051256/htt...
# 19  https://web.archive.org/web/20141002042854/htt...
# 20  https://web.archive.org/web/20140806180244/htt...
# 21  https://web.archive.org/web/20140928174742/htt...
# 22  https://web.archive.org/web/20140915101052/htt...
# 23  https://web.archive.org/web/20200914092027/htt...
# 24  https://web.archive.org/web/20220826002738/htt...
# 25  https://web.archive.org/web/20130809082030/htt...
# 26  https://web.archive.org/web/20130825031606/htt...
# 27  https://web.archive.org/web/20130928065523/htt...
# 28  https://web.archive.org/web/20141026235254/htt...
# 29  https://web.archive.org/web/20140517191339/htt...
# 30  https://web.archive.org/web/20191207132536/htt...
# 31  https://web.archive.org/web/20111005032637/htt...
# 32  https://web.archive.org/web/20100416004248/htt...
# 33  https://web.archive.org/web/20210730170138/htt...
# 34  https://web.archive.org/web/20221010030355/htt...
# 35  https://web.archive.org/web/20220610053636/htt...
# 36  https://web.archive.org/web/20220717050854/htt...
# 37  https://web.archive.org/web/20220708195908/htt...
# 38  https://web.archive.org/web/20190524071912/htt...
# 39  https://web.archive.org/web/20191102003919/htt...
# 40  https://web.archive.org/web/20191204010531/htt...
# 41  https://web.archive.org/web/20190709011647/htt...
# 42  https://web.archive.org/web/20190814161555/htt...
# 43  https://web.archive.org/web/20190826132735/htt...
# 44  https://web.archive.org/web/20200118031548/htt...
# 45  https://web.archive.org/web/20200113014442/htt...
# 46  https://web.archive.org/web/20200117234418/htt...
# 47  https://web.archive.org/web/20200202091433/htt...
# 48  https://web.archive.org/web/20200209015257/htt...
# 49  https://web.archive.org/web/20210430091952/htt...
#
#                                  serp_wayback_raw_url  serp_page  serp_offset  \
# 0   https://web.archive.org/web/20220103031444id_/...        NaN          NaN
# 1   https://web.archive.org/web/20030831215434id_/...        NaN          NaN
# 2   https://web.archive.org/web/20130528164211id_/...        NaN          NaN
# 3   https://web.archive.org/web/20141019085318id_/...        NaN          NaN
# 4   https://web.archive.org/web/20210420174732id_/...        NaN          NaN
# 5   https://web.archive.org/web/20190620044546id_/...        NaN          NaN
# 6   https://web.archive.org/web/20200223100201id_/...        NaN          NaN
# 7   https://web.archive.org/web/20200626134854id_/...        NaN          NaN
# 8   https://web.archive.org/web/20210225233047id_/...        NaN          NaN
# 9   https://web.archive.org/web/20210224181505id_/...        NaN          NaN
# 10  https://web.archive.org/web/20210224075606id_/...        NaN          NaN
# 11  https://web.archive.org/web/20210225224410id_/...        NaN          NaN
# 12  https://web.archive.org/web/20210224052653id_/...        NaN          NaN
# 13  https://web.archive.org/web/20210224033612id_/...        NaN          NaN
# 14  https://web.archive.org/web/20210304075706id_/...        NaN          NaN
# 15  https://web.archive.org/web/20120105213608id_/...        NaN          NaN
# 16  https://web.archive.org/web/20130506135023id_/...        NaN          NaN
# 17  https://web.archive.org/web/20130613094617id_/...        NaN          NaN
# 18  https://web.archive.org/web/20141007051256id_/...        NaN          NaN
# 19  https://web.archive.org/web/20141002042854id_/...        NaN          NaN
# 20  https://web.archive.org/web/20140806180244id_/...        NaN          NaN
# 21  https://web.archive.org/web/20140928174742id_/...        NaN          NaN
# 22  https://web.archive.org/web/20140915101052id_/...        NaN          NaN
# 23  https://web.archive.org/web/20200914092027id_/...        NaN          NaN
# 24  https://web.archive.org/web/20220826002738id_/...        NaN          NaN
# 25  https://web.archive.org/web/20130809082030id_/...        NaN          NaN
# 26  https://web.archive.org/web/20130825031606id_/...        NaN          NaN
# 27  https://web.archive.org/web/20130928065523id_/...        NaN          NaN
# 28  https://web.archive.org/web/20141026235254id_/...        NaN          NaN
# 29  https://web.archive.org/web/20140517191339id_/...        NaN          NaN
# 30  https://web.archive.org/web/20191207132536id_/...        NaN          NaN
# 31  https://web.archive.org/web/20111005032637id_/...        NaN          NaN
# 32  https://web.archive.org/web/20100416004248id_/...        NaN          NaN
# 33  https://web.archive.org/web/20210730170138id_/...        NaN          NaN
# 34  https://web.archive.org/web/20221010030355id_/...        NaN          NaN
# 35  https://web.archive.org/web/20220610053636id_/...        NaN          NaN
# 36  https://web.archive.org/web/20220717050854id_/...        NaN          NaN
# 37  https://web.archive.org/web/20220708195908id_/...        NaN          NaN
# 38  https://web.archive.org/web/20190524071912id_/...        NaN          NaN
# 39  https://web.archive.org/web/20191102003919id_/...        NaN          NaN
# 40  https://web.archive.org/web/20191204010531id_/...        NaN          NaN
# 41  https://web.archive.org/web/20190709011647id_/...        NaN          NaN
# 42  https://web.archive.org/web/20190814161555id_/...        NaN          NaN
# 43  https://web.archive.org/web/20190826132735id_/...        NaN          NaN
# 44  https://web.archive.org/web/20200118031548id_/...        NaN          NaN
# 45  https://web.archive.org/web/20200113014442id_/...        NaN          NaN
# 46  https://web.archive.org/web/20200117234418id_/...        NaN          NaN
# 47  https://web.archive.org/web/20200202091433id_/...        NaN          NaN
# 48  https://web.archive.org/web/20200209015257id_/...        NaN          NaN
# 49  https://web.archive.org/web/20210430091952id_/...        NaN          NaN
#
#                                   serp_query_text_url  \
# 0                               "FKジェレズニク" -wikipedia
# 1                          "ASP"   "Microsoft Access"
# 2                                          asano yuga
# 3                           EurovisionSongContest2014
# 4                                        #songhyekyo#
# 5   Tripanosomas semelhantes do Trypanosoma cruzi ...
# 6   Genetic exchange among bdelloid rotifers is mo...
# 7                  author:"van der Wouden Johannes C"
# 8   Päivi Majaranta and Kari Jouko Räihä. 2002. Tw...
# 9   Lützenberger, M., Ahrndt, S., Hirsch, B., Masu...
# 10  Jingjin Yu and Steven M. LaValle. 2016. Optima...
# 11  A.Reyhani-Maoleh, and Hasan, M. A. A new const...
# 12  Mrinmoy Ghosh, Emre Özer, Simon Ford, Stuart B...
# 13  Barnsley, M. F. and Hurd, L. P. 1993, Fractal ...
# 14  Tao Zheng, Jinmei Yang, Murray Woodside, Marin...
# 15                                            membase
# 16                                         flash+mpeg
# 17                           android+reference+memory
# 18                           autoplay+jquery+slidesjs
# 19                                    ecm+dms+filenet
# 20                        oracle+oracle11g+sql-server
# 21                            background+service+bind
# 22  user-defined-functions+mysql+stored-procedures...
# 23       azure-active-directory+azure-virtual-machine
# 24                                   opencv+image+cv2
# 25                                       #RIO2trailer
# 26                                         #etnogenez
# 27                                           #OnPulse
# 28                                            #SYNNEX
# 29                                            #УкрТві
# 30                                             #Iwata
# 31                                  site:61300.com 景色
# 32                       +nelson band members charges
# 33                                      devops resume
# 34                                         PlatinumSn
# 35                    inauthor:"Ben Witherington III"
# 36  "A confiança interorganizacional nas compras" ...
# 37         "Mentira (Karoll Márquez song)" -wikipedia
# 38  prerequisites for the establishment of nuclear...
# 39                     как правильно косить мотокосой
# 40                                     вольвич подача
# 41                            гималайская соль монтаж
# 42                            металлоискатель md 3010
# 43                              дымогенератор g-smoke
# 44                               мистер кот майнкрафт
# 45                                        ветреный 23
# 46                                 шп прист 8.2.5 пве
# 47                     лего ниндзяго набор дракон кая
# 48                                     #прогнозпогоды
# 49                          "Andris Marts" -wikipedia
#
#    serp_query_text_url_language  \
# 0                            kk
# 1                           NaN
# 2                            ja
# 3                            ky
# 4                           NaN
# 5                            pt
# 6                           NaN
# 7                            nl
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                           en
# 12                           en
# 13                           en
# 14                           en
# 15                           id
# 16                          NaN
# 17                           en
# 18                           lv
# 19                          NaN
# 20                           af
# 21                           de
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                           sr
# 27                          NaN
# 28                           cy
# 29                          NaN
# 30                           ha
# 31                           pt
# 32                           en
# 33                          NaN
# 34                          NaN
# 35                           xh
# 36                           pt
# 37                          NaN
# 38                           en
# 39                           ru
# 40                          NaN
# 41                           ru
# 42                          NaN
# 43                           kk
# 44                           mk
# 45                           ru
# 46                           sr
# 47                           uk
# 48                          NaN
# 49                          NaN
#
#                                  serp_query_text_html  ...  \
# 0                               "FKジェレズニク" -wikipedia  ...
# 1                          "ASP"   "Microsoft Access"  ...
# 2                                          asano yuga  ...
# 3                           EurovisionSongContest2014  ...
# 4                                        #songhyekyo#  ...
# 5   Tripanosomas semelhantes do Trypanosoma cruzi ...  ...
# 6   Genetic exchange among bdelloid rotifers is mo...  ...
# 7                  author:"van der Wouden Johannes C"  ...
# 8   Päivi Majaranta and Kari Jouko Räihä. 2002. Tw...  ...
# 9   Lützenberger, M., Ahrndt, S., Hirsch, B., Masu...  ...
# 10  Jingjin Yu and Steven M. LaValle. 2016. Optima...  ...
# 11  A.Reyhani-Maoleh, and Hasan, M. A. A new const...  ...
# 12  Mrinmoy Ghosh, Emre Özer, Simon Ford, Stuart B...  ...
# 13  Barnsley, M. F. and Hurd, L. P. 1993, Fractal ...  ...
# 14  Tao Zheng, Jinmei Yang, Murray Woodside, Marin...  ...
# 15                                          [membase]  ...
# 16                                     [flash] [mpeg]  ...
# 17                     [android] [reference] [memory]  ...
# 18                     [autoplay] [jquery] [slidesjs]  ...
# 19                              [ecm] [dms] [filenet]  ...
# 20                  [oracle] [oracle11g] [sql-server]  ...
# 21                      [background] [service] [bind]  ...
# 22  [user-defined-functions] [mysql] [stored-proce...  ...
# 23   [azure-active-directory] [azure-virtual-machine]  ...
# 24                             [opencv] [image] [cv2]  ...
# 25                                               None  ...
# 26                                               None  ...
# 27                                               None  ...
# 28                                               None  ...
# 29                                               None  ...
# 30                                               None  ...
# 31                                  site:61300.com 景色  ...
# 32                       +nelson band members charges  ...
# 33                                      devops resume  ...
# 34                                         PlatinumSn  ...
# 35                    inauthor:"Ben Witherington III"  ...
# 36  "A confiança interorganizacional nas compras" ...  ...
# 37         "Mentira (Karoll Márquez song)" -wikipedia  ...
# 38  prerequisites for the establishment of nuclear...  ...
# 39                     как правильно косить мотокосой  ...
# 40                                     вольвич подача  ...
# 41                            гималайская соль монтаж  ...
# 42                            металлоискатель md 3010  ...
# 43                              дымогенератор g-smoke  ...
# 44                               мистер кот майнкрафт  ...
# 45                                        ветреный 23  ...
# 46                                 шп прист 8.2.5 пве  ...
# 47                     лего ниндзяго набор дракон кая  ...
# 48                                     #прогнозпогоды  ...
# 49                          "Andris Marts" -wikipedia  ...
#
#                                          serp_results  search_provider_name  \
# 0   [{'result_id': 'ea1b3af7-ba83-59d3-87b0-c508ed...                google
# 1   [{'result_id': 'c9661b3e-d736-5b81-a3fe-e97c4f...                google
# 2                                                  []              facebook
# 3   [{'result_id': 'e65e2155-ec92-5073-9d82-15cca0...               twitter
# 4                                                  []                 weibo
# 5                                                  []                google
# 6                                                  []                google
# 7                                                  []                google
# 8                                                  []                google
# 9                                                  []                google
# 10                                                 []                google
# 11                                                 []                google
# 12                                                 []                google
# 13                                                 []                google
# 14                                                 []                google
# 15  [{'result_id': 'd205d034-f062-5513-bb08-68d41d...         stackoverflow
# 16  [{'result_id': '26a06664-f859-5e70-8e25-a86558...         stackoverflow
# 17  [{'result_id': 'd92736c5-e4ba-5107-93e7-e3d129...         stackoverflow
# 18  [{'result_id': '26f5a6ef-9955-55b1-beae-1932d3...         stackoverflow
# 19  [{'result_id': 'b144c8d9-4fbf-5e23-9115-a70b9b...         stackoverflow
# 20  [{'result_id': '26f0106d-51be-5159-8ba0-6dfb50...         stackoverflow
# 21  [{'result_id': 'a792c702-ebef-5f5d-8355-00bd02...         stackoverflow
# 22  [{'result_id': 'e4d53dee-47ad-5b33-99c5-dc6d74...         stackoverflow
# 23  [{'result_id': 'ce5a29f6-d103-543a-8701-6a16e0...         stackoverflow
# 24  [{'result_id': 'd6cd7995-3b1b-52d3-9eff-f1f0b8...         stackoverflow
# 25  [{'result_id': '381ca986-c96b-5325-a25c-60f4fc...               twitter
# 26  [{'result_id': '0e5d0e6c-035c-5bf3-b562-4f3eec...               twitter
# 27  [{'result_id': '6ff4605c-c16d-5d66-b3b8-fd5ca4...               twitter
# 28  [{'result_id': 'f1ddf521-560a-5564-aba7-934148...               twitter
# 29  [{'result_id': 'a4e1b7e6-ebcf-59bf-8d93-b41183...               twitter
# 30  [{'result_id': '5011ceab-f538-5a17-99ea-d270b7...               twitter
# 31                                                 []                 baidu
# 32  [{'result_id': '8763ccaf-8d5d-5559-9255-dbe0b2...                  bing
# 33  [{'result_id': '12cf4a9b-fa59-5e00-a03a-6c44cf...                google
# 34  [{'result_id': '1b314f8b-90b7-5aa0-918a-99a934...                google
# 35  [{'result_id': '3e079aab-6876-549a-9478-2d99d0...                google
# 36  [{'result_id': 'cbd5595e-5b37-518f-b6be-c9f3aa...                google
# 37  [{'result_id': 'd7025214-d786-5fa4-b68c-cd6c1a...                google
# 38  [{'result_id': 'beccab7d-244c-562a-b779-68f0ef...                 sogou
# 39  [{'result_id': '9f182404-d9a5-53b8-bb61-8a64f7...               youtube
# 40  [{'result_id': '069daf23-59f2-5902-a38f-db6074...               youtube
# 41  [{'result_id': 'ca379346-affb-59da-ae2e-5f1032...               youtube
# 42  [{'result_id': '0dc09184-2be7-52d9-9704-0e52bf...               youtube
# 43  [{'result_id': '0e6decd2-0e4a-58c7-89f5-4e89f1...               youtube
# 44  [{'result_id': '66587c6b-d38d-5f61-9603-8685b3...               youtube
# 45  [{'result_id': '528cc697-cbbb-551e-9a2e-7e597a...               youtube
# 46  [{'result_id': '6e58f0e6-103e-57c3-a39e-78e0eb...               youtube
# 47  [{'result_id': '7cd69b25-fbdc-5b72-b7e1-367b52...               youtube
# 48  [{'result_id': '215cc0c4-406b-5894-ad66-467c2a...               youtube
# 49  [{'result_id': '3f40417f-4110-54df-acc6-bed5f0...                google
#
#    search_provider_alexa_domain search_provider_alexa_domain_public_suffix  \
# 0                    google.com                                        com
# 1                    google.com                                        com
# 2                  facebook.com                                        com
# 3                   twitter.com                                        com
# 4                     weibo.com                                        com
# 5                    google.com                                        com
# 6                    google.com                                        com
# 7                    google.com                                        com
# 8                    google.com                                        com
# 9                    google.com                                        com
# 10                   google.com                                        com
# 11                   google.com                                        com
# 12                   google.com                                        com
# 13                   google.com                                        com
# 14                   google.com                                        com
# 15            stackoverflow.com                                        com
# 16            stackoverflow.com                                        com
# 17            stackoverflow.com                                        com
# 18            stackoverflow.com                                        com
# 19            stackoverflow.com                                        com
# 20            stackoverflow.com                                        com
# 21            stackoverflow.com                                        com
# 22            stackoverflow.com                                        com
# 23            stackoverflow.com                                        com
# 24            stackoverflow.com                                        com
# 25                  twitter.com                                        com
# 26                  twitter.com                                        com
# 27                  twitter.com                                        com
# 28                  twitter.com                                        com
# 29                  twitter.com                                        com
# 30                  twitter.com                                        com
# 31                    baidu.com                                        com
# 32                     bing.com                                        com
# 33                   google.com                                        com
# 34                   google.com                                        com
# 35                   google.com                                        com
# 36                   google.com                                        com
# 37                   google.com                                        com
# 38                    sogou.com                                        com
# 39                  youtube.com                                        com
# 40                  youtube.com                                        com
# 41                  youtube.com                                        com
# 42                  youtube.com                                        com
# 43                  youtube.com                                        com
# 44                  youtube.com                                        com
# 45                  youtube.com                                        com
# 46                  youtube.com                                        com
# 47                  youtube.com                                        com
# 48                  youtube.com                                        com
# 49                   google.com                                        com
#
#    search_provider_alexa_rank search_provider_category  \
# 0                           1            search-engine
# 1                           1            search-engine
# 2                           5             social-media
# 3                          26             social-media
# 4                          15             social-media
# 5                           1            search-engine
# 6                           1            search-engine
# 7                           1            search-engine
# 8                           1            search-engine
# 9                           1            search-engine
# 10                          1            search-engine
# 11                          1            search-engine
# 12                          1            search-engine
# 13                          1            search-engine
# 14                          1            search-engine
# 15                         43      question-and-answer
# 16                         43      question-and-answer
# 17                         43      question-and-answer
# 18                         43      question-and-answer
# 19                         43      question-and-answer
# 20                         43      question-and-answer
# 21                         43      question-and-answer
# 22                         43      question-and-answer
# 23                         43      question-and-answer
# 24                         43      question-and-answer
# 25                         26             social-media
# 26                         26             social-media
# 27                         26             social-media
# 28                         26             social-media
# 29                         26             social-media
# 30                         26             social-media
# 31                          3            search-engine
# 32                         25            search-engine
# 33                          1            search-engine
# 34                          1            search-engine
# 35                          1            search-engine
# 36                          1            search-engine
# 37                          1            search-engine
# 38                         73            search-engine
# 39                          2            media-sharing
# 40                          2            media-sharing
# 41                          2            media-sharing
# 42                          2            media-sharing
# 43                          2            media-sharing
# 44                          2            media-sharing
# 45                          2            media-sharing
# 46                          2            media-sharing
# 47                          2            media-sharing
# 48                          2            media-sharing
# 49                          1            search-engine
#
#     serp_domain_public_suffix         serp_domain serp_year serp_month
# 0                       co.jp    www.google.co.jp      2022          1
# 1                      com.sg   www.google.com.sg      2003          8
# 2                         com  ja-jp.facebook.com      2013          5
# 3                         com  mobile.twitter.com      2014         10
# 4                         com         s.weibo.com      2021          4
# 5                         com  scholar.google.com      2019          6
# 6                         com  scholar.google.com      2020          2
# 7                         com  scholar.google.com      2020          6
# 8                         com  scholar.google.com      2021          2
# 9                         com  scholar.google.com      2021          2
# 10                        com  scholar.google.com      2021          2
# 11                        com  scholar.google.com      2021          2
# 12                        com  scholar.google.com      2021          2
# 13                        com  scholar.google.com      2021          2
# 14                        com  scholar.google.com      2021          3
# 15                        com   stackoverflow.com      2012          1
# 16                        com   stackoverflow.com      2013          5
# 17                        com   stackoverflow.com      2013          6
# 18                        com   stackoverflow.com      2014         10
# 19                        com   stackoverflow.com      2014         10
# 20                        com   stackoverflow.com      2014          8
# 21                        com   stackoverflow.com      2014          9
# 22                        com   stackoverflow.com      2014          9
# 23                        com   stackoverflow.com      2020          9
# 24                        com   stackoverflow.com      2022          8
# 25                        com         twitter.com      2013          8
# 26                        com         twitter.com      2013          8
# 27                        com         twitter.com      2013          9
# 28                        com         twitter.com      2014         10
# 29                        com         twitter.com      2014          5
# 30                        com         twitter.com      2019         12
# 31                        com       www.baidu.com      2011         10
# 32                        com        www.bing.com      2010          4
# 33                        com      www.google.com      2021          7
# 34                        com      www.google.com      2022         10
# 35                        com      www.google.com      2022          6
# 36                        com      www.google.com      2022          7
# 37                        com      www.google.com      2022          7
# 38                        com       www.sogou.com      2019          5
# 39                        com     www.youtube.com      2019         11
# 40                        com     www.youtube.com      2019         12
# 41                        com     www.youtube.com      2019          7
# 42                        com     www.youtube.com      2019          8
# 43                        com     www.youtube.com      2019          8
# 44                        com     www.youtube.com      2020          1
# 45                        com     www.youtube.com      2020          1
# 46                        com     www.youtube.com      2020          1
# 47                        com     www.youtube.com      2020          2
# 48                        com     www.youtube.com      2020          2
# 49                         lv       www.google.lv      2021          4
#
# [50 rows x 22 columns]

# %%
with example_results_path_json.open("rt") as example_results_file:
    example_results = [loads(line) for line in example_results_file]

# %%
from archive_query_log.schema import RESULT_SCHEMA

results_table = table(
    data={
        "result_id": [result["id"] for result in example_results],
        "result_url": [result["url"] for result in example_results],
        "result_domain": [domain(result["url"]) for result in example_results],
        "result_domain_public_suffix": [public_suffix(result["url"]) for result in example_results],
        "result_wayback_url": [result["wayback_url"] for result in example_results],
        "result_wayback_raw_url": [result["wayback_raw_url"] for result in example_results],
        "result_snippet_rank": [result["snippet_rank"] for result in example_results],
        "result_snippet_title": [result["snippet_title"] for result in example_results],
        "result_snippet_text": [result["snippet_text"] for result in example_results],
        "result_warc_relative_path": [None for result in example_results],
        "result_warc_byte_offset": [None for result in example_results],
        "serp_id": [result["query"]["id"] for result in example_results],
        "serp_url": [result["query"]["url"] for result in example_results],
        "serp_domain": [domain(result["query"]["url"]) for result in example_results],
        "serp_domain_public_suffix": [public_suffix(result["query"]["url"]) for result in example_results],
        "serp_timestamp": [result["query"]["timestamp"] for result in example_results],
        "serp_year": [year(result["query"]["timestamp"]) for result in example_results],
        "serp_month": [month(result["query"]["timestamp"]) for result in example_results],
        "serp_wayback_url": [result["query"]["wayback_url"] for result in example_results],
        "serp_wayback_raw_url": [result["query"]["wayback_raw_url"] for result in example_results],
        "serp_page": [result["query"]["url_page"] for result in example_results],
        "serp_offset": [result["query"]["url_offset"] for result in example_results],
        "serp_query_text_url": [result["query"]["url_query"] for result in example_results],
        "serp_query_text_url_language": [result["query"]["language"] for result in example_results],
        "serp_query_text_html": [result["query"]["serp_query"] for result in example_results],
        "serp_warc_relative_path":
            [result["query"]["archived_raw_serp_location"]["relative_path"] for result in example_results],
        "serp_warc_byte_offset":
            [result["query"]["archived_raw_serp_location"]["byte_offset"] for result in example_results],
        "search_provider_name": [result["query"]["service"] for result in example_results],
        "search_provider_alexa_domain":
            [search_provider(result["query"]["service"])["alexa_domain"] for result in example_results],
        "search_provider_alexa_domain_public_suffix":
            [search_provider(result["query"]["service"])["alexa_public_suffix"] for result in example_results],
        "search_provider_alexa_rank":
            [search_provider(result["query"]["service"])["alexa_rank"] for result in example_results],
        "search_provider_category":
            [search_provider(result["query"]["service"])["category"] for result in example_results],
    },
    schema=RESULT_SCHEMA,
)

# %%
from archive_query_log.schema import RESULT_PARTITIONING

if example_results_dir.exists():
    rmtree(example_results_dir)
example_results_dir.mkdir()
write_to_dataset(
    results_table,
    root_path=example_results_dir_parquet,
    partitioning=RESULT_PARTITIONING,
    basename_template="results_{i}.parquet",
)
for path in example_results_dir_parquet.rglob("**/*.parquet"):
    df = read_parquet(path)
    rel_path = path.relative_to(example_results_dir_parquet)
    csv_path = (example_results_dir_csv / rel_path).with_suffix(".csv")
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(csv_path, index=False)
    jsonl_path = (example_results_dir_jsonl / rel_path).with_suffix(".json")
    jsonl_path.parent.mkdir(parents=True, exist_ok=True)
    df.to_json(jsonl_path, orient="records", lines=True)
make_archive(example_results_dir, "zip", example_results_dir)
# Out:
# '/home/heinrich/Repositories/archive-query-log/data/examples/results.zip'

# %%
from pandas import read_parquet

read_parquet(example_results_dir_parquet).sort_values(["serp_id", "result_snippet_rank"])
# 48  https://www.ebay.it/itm/252135139110?hash=item...            www.ebay.it
# 45  https://www.amazon.es/Krups-Nespresso-YY1531FD...          www.amazon.es
# 7                            https://go.factor75.com/        go.factor75.com
# 0     http://www.obj-sys.com/products/asn1c/index.php        www.obj-sys.com
# 36        https://www.youtube.com/watch?v=urcV8pBfyGE        www.youtube.com
# 19  https://www.ebay.com/itm/King-James-Version-KJ...           www.ebay.com
# 33        https://www.youtube.com/watch?v=KcGidWybaLk        www.youtube.com
# 32        https://www.youtube.com/watch?v=dTCzHtBsYMo        www.youtube.com
# 12  https://stackoverflow.com/questions/36531009/m...      stackoverflow.com
#
#    result_domain_public_suffix  \
# 30                         com
# 23                         org
# 21                         com
# 44                         com
# 13                         com
# 3                       com.au
# 38                         com
# 46                          fr
# 41                         com
# 6                          com
# 29                         com
# 47                          in
# 37                         com
# 15                         com
# 18                         com
# 43                         com
# 42                         com
# 27                         com
# 4                       com.br
# 16                         com
# 25                         com
# 14                         com
# 9                          com
# 34                         com
# 40                         com
# 10                         com
# 39                         com
# 1                        co.jp
# 8                          com
# 24                         com
# 35                         com
# 5                          com
# 31                         com
# 2                        co.uk
# 11                         com
# 22                         com
# 49                          lv
# 28                         com
# 26                         com
# 20                      com.mx
# 17                         com
# 48                          it
# 45                          es
# 7                          com
# 0                          com
# 36                         com
# 19                         com
# 33                         com
# 32                         com
# 12                         com
#
#                                    result_wayback_url  \
# 30  https://web.archive.org/web/20191025135059/htt...
# 23  https://web.archive.org/web/20210423062233/htt...
# 21  https://web.archive.org/web/20210114133654/htt...
# 44  https://web.archive.org/web/20210909025649/htt...
# 13  https://web.archive.org/web/20200518111006/htt...
# 3   https://web.archive.org/web/20200108102227/htt...
# 38  https://web.archive.org/web/20200114111916/htt...
# 46  https://web.archive.org/web/20211026163403/htt...
# 41  https://web.archive.org/web/20200131213730/htt...
# 6   https://web.archive.org/web/20140920090721/htt...
# 29  https://web.archive.org/web/20200320081358/htt...
# 47  https://web.archive.org/web/20220903153603/htt...
# 37  https://web.archive.org/web/20190915062405/htt...
# 15  https://web.archive.org/web/20210126030420/htt...
# 18  https://web.archive.org/web/20220624032253/htt...
# 43  https://web.archive.org/web/20180211144933/htt...
# 42  https://web.archive.org/web/20200203014735/htt...
# 27  https://web.archive.org/web/20220516145933/htt...
# 4   https://web.archive.org/web/20211021225449/htt...
# 16  https://web.archive.org/web/20220224025221/htt...
# 25  https://web.archive.org/web/20220210005850/htt...
# 14  https://web.archive.org/web/20150627043200/htt...
# 9   https://web.archive.org/web/20171025082333/htt...
# 34  https://web.archive.org/web/20190628110055/htt...
# 40  https://web.archive.org/web/20200122162818/htt...
# 10  https://web.archive.org/web/20191114205402/htt...
# 39  https://web.archive.org/web/20200123212513/htt...
# 1   https://web.archive.org/web/20220807000223/htt...
# 8   https://web.archive.org/web/20140922114935/htt...
# 24  https://web.archive.org/web/20210930115827/htt...
# 35  https://web.archive.org/web/20190728133048/htt...
# 5   https://web.archive.org/web/20120617025631/htt...
# 31  https://web.archive.org/web/20191124161331/htt...
# 20  https://web.archive.org/web/20201228223408id_/...                    1
# 17  https://web.archive.org/web/20220812075859id_/...                   10
# 48  https://web.archive.org/web/20220829062747id_/...                   38
# 45  https://web.archive.org/web/20220315172424id_/...                   25
# 7   https://web.archive.org/web/20220728161422id_/...                    1
# 0   https://web.archive.org/web/20210608175949id_/...                    7
# 36  https://web.archive.org/web/20190709063118id_/...                    4
# 19  https://web.archive.org/web/20210221152416id_/...                   13
# 33  https://web.archive.org/web/20190627072802id_/...                    3
# 32  https://web.archive.org/web/20191105095616id_/...                   25
# 12  https://web.archive.org/web/20190301211314id_/...                   13
#
#                                  result_snippet_title  \
# 30  Search hidden 'R' found in the New World Loadi...
# 23  What Biden's Climate Plan Means For Regenerati...
# 21                          Angela Merkel – Wikipédia
# 44  Nail Art Express в Twitter: "Just posted a vid...
# 13  Cracks in webaudio playback during streaming o...
# 3   DIY LED Dash Cluster Light Bulbs VT VX VU WHCo...
# 38  Основные ошибки бариста в работе с кофемашиной...
# 46  CRYSTAL AURUM 2X 001 AUR2 Swarovski 5328 Xilio...
# 41  Batman Arkham | 1 сезон | 1 серия - Продолжите...
# 6        <em>iPhoneDeveloper.Me</em>\n\n@iPhoneDev_Me
# 29                            氢<em>羟吗啡酮</em>| 76-41-5
# 47                           FUSE 27L BACKPACK MAGNET
# 37  Сваты 4 (4-й сезон, 14-я серия) - Продолжитель...
# 15  Peora Created White Opal Earrings and Pendant ...
# 18  <em>FAG bearing designation | nomenclature | p...
# 43  Orders and Resolutions, Made at a General Meet...
# 42  Колесо обозрения-Судак, стоимость, отличный ви...
# 27                              컴퓨터, 전자제품 종합쇼핑몰 - 컴퓨존
# 4      Kingdom Hearts: Melody Of Memory PlayStation 4
# 16  Micro Center AMD Ryzen 9 5950X 16-Core 32-Thre...
# 25  Getting compilers right: a reliable foundation...
# 14  2015 nuevo verano Tops camisetas de fútbol del...
# 9   How to Compile a c program in clang exactly th...
# 34   공기청정기, 환기청정기, 열회수환기장치 - Продолжительность: 10:15
# 40         Johnny Cash - Wanted Man - Duration: 2:53.
# 10       How to pass SlackEvents data to client side?
# 39  제1회 김천 전국동호인테니스대회 지도자부 결승 김창민 한주호/최환용 정성훈 - Пр...
# 1                  賢いママは【Yahoo!天気】で毎日をもっと便利に楽しくしています！
# 8                         Update Gridview in realtime
# 24                        Farms Compete With Suburbs.
# 35  wild rose - 너를 기억하며.mp4 - Продолжительность: 4:29
# 5                          <em>ACHORD</em>\n\n@Ach0rd
# 31  Lovelyz(러블리즈) - Lost N Found(찾아가세요)(piano cove...
# 2   HP EliteBook 840 G1 plus FREE Mobile Broadband...
# 11  Can't connect to azure DevOps TFVC from VS 201...
# 22  A moon of a different color | Tracy Press Our ...
# 49  NOSLĒPUMAINĀS UPES STĀSTI / Andris Marts - Jau...
# 28  Character Analysis Of Thomas Putnam In The Cru...
# 26  C&amp;F - Translation into English - examples ...
# 20  No te voy a pedir que hagas nada. Porque si te...
# 17  德语助手|德汉-汉德词典 <em>COMECON</em>是什么意思_<em>COMECON...
# 48  MATERASSO ALLA FRANCESE 140X200 H22 CM MEMORY ...
# 45  Krups Nespresso Inissia Rouge YY1531FD Indepen...
# 7   go.factor75.com<em>Factor</em>_ | <em>Healthy,...
# 0          ASN.1 Compiler - ASN1C - Objective Systems
# 36  ASL 시즌4 결승전 아프리카 스타 리그, 이영호 VS 조일장 FINALS MATC...
# 19  King James Version (KJV) Lion - Humble Lamb Bi...
# 33  Как самостоятельно заполнить декларацию 3-НДФЛ...
# 32  INSTALLING NETBEANS 11 ON LINUX - Продолжитель...
# 12                        MPI too many communicators?
#
#                                   result_snippet_text  \
# 30  Support A Creator code - inthelittlewood Twitc...
# 23  1 Feb 2021 — President Joe <em>Biden</em> has ...
# 21                                               None
# 44  <em>Nail Art Express</em> · @NailartBd. First ...
# 13  I have a server sending chunks of raw audio ov...
# 3                                                None
# 38  Наш новый ролик посвящен основным ошибкам бари...
# 46                                               None
# 41                                               None
# 6   No more reboots: it’s time for Hollywood to st...
# 29                                               None
# 47                                               None
# 37  Четырнадцатая <em>серия</em>. Для участия в ко...
# 15                                               None
# 18  For example: FAG deep groove ball <em>bearing ...
# 43  Bedford Level Corporation - ‎1771 - Keine Vors...
# 42  Всем привет! Приглашаем прокатиться вместе с н...
# 27                                               None
# 4                                                None
# 16                                               None
# 25                                               None
# 14                                               None
# 9   I want to evaluate an AVX2 program written in ...
# 34  공기를 깨끗하게 해주거나 <em>환기</em>를 해주는 여러 장치들의 특성을 알아 ...
# 40  I do not own or claim any of this copyrighted ...
# 10  I'm trying to create a simple chat based of th...
# 39                                               None
# 1                                                None
# 8   I'm developing application WinForms .net 4.0 u...
# 24                                               None
# 35                  懐かしい音楽俺と同時代を生きて来た人には懐かしい音楽だとおもうわ.
# 5   Edmonton is #1 automobile dependent city in Ca...
# 31  I hope you enjoy Snail's cover of Lost N Found...
# 2   Over 30000 products with <em>FREE</em> DELIVER...
# 11  Using Azure DevOps with TFVC - I can't connect...
# 22  “Wolf moon” is a traditional name for January'...
# 49                                               None
# 28                                               None
# 26                                               None
# 20  No te voy a pedir que hagas nada. Porque si te...
# 17                                               None
# 48                                               None
# 45                                               None
# 7   Jan 31, 2015 ·  Just heat, eat, and enjoy. Our...
# 0   The ASN1C <em>ASN.1 compiler</em> translates A...
# 36  이영호의 아프리카 방송국 바로가기! : http://www.afreeca.com/b...
# 19                                               None
# 33  Вычет по предыдущим годам <em>декларации</em>....
# 32  How to Install Apache <em>NetBeans</em> 11.0 o...
# 12  The idea of the code is to open a file in para...
#
#    result_warc_relative_path  ...  serp_warc_byte_offset search_provider_name  \
# 30                      None  ...               57442749              youtube
# 23                      None  ...                 420323               google
# 21                      None  ...                2356073               google
# 44                      None  ...                 923796               google
# 13                      None  ...                 451128        stackoverflow
# 3                       None  ...               60569302                 ebay
# 38                      None  ...                 152074              youtube
# 46                      None  ...                 162515                 ebay
# 41                      None  ...                 915447              youtube
# 6                       None  ...                 126553              twitter
# 29                      None  ...               39015552                  360
# 47                      None  ...                9108121               amazon
# 37                      None  ...                    573              youtube
# 15                      None  ...                 534377               amazon
# 18                      None  ...               46489586                 bing
# 43                      None  ...                 190243               google
# 42                      None  ...                 387589              youtube
# 27                      None  ...                 152765               google
# 4                       None  ...               68559915               amazon
# 16                      None  ...                 705297               amazon
# 25                      None  ...                 293769               google
# 14                      None  ...                 513050           aliexpress
# 9                       None  ...                 702651        stackoverflow
# 34                      None  ...                 667176              youtube
# 40                      None  ...               33352158              youtube
# 10                      None  ...                 530857        stackoverflow
# 39                      None  ...                1476054              youtube
# 1                       None  ...                 414628               google
# 8                       None  ...                  36018        stackoverflow
# 24                      None  ...                 769003               google
# 35                      None  ...                 624968              youtube
# 5                       None  ...                  44938              twitter
# 31                      None  ...                 109101              youtube
# 2                       None  ...                4809840               google
# 11                      None  ...                 291627        stackoverflow
# 22                      None  ...                4424958               google
# 49                      None  ...                 323042               google
# 28                      None  ...                    646               google
# 26                      None  ...                1725055               google
# 20                      None  ...                1481808               google
# 17                      None  ...                    517                baidu
# 48                      None  ...               28385865                 ebay
# 45                      None  ...               73865760               amazon
# 7                       None  ...               66070674                yahoo
# 0                       None  ...                 131726               google
# 36                      None  ...              161835557              youtube
# 19                      None  ...                 148794                 ebay
# 33                      None  ...                 201024              youtube
# 32                      None  ...                 507751              youtube
# 12                      None  ...                 187520        stackoverflow
#
#    search_provider_alexa_domain search_provider_alexa_domain_public_suffix  \
# 30                  youtube.com                                        com
# 23                   google.com                                        com
# 21                   google.com                                        com
# 44                   google.com                                        com
# 13            stackoverflow.com                                        com
# 3                      ebay.com                                        com
# 38                  youtube.com                                        com
# 46                     ebay.com                                        com
# 41                  youtube.com                                        com
# 6                   twitter.com                                        com
# 29                       360.cn                                         cn
# 47                   amazon.com                                        com
# 37                  youtube.com                                        com
# 15                   amazon.com                                        com
# 18                     bing.com                                        com
# 43                   google.com                                        com
# 42                  youtube.com                                        com
# 27                   google.com                                        com
# 4                    amazon.com                                        com
# 16                   amazon.com                                        com
# 25                   google.com                                        com
# 14               aliexpress.com                                        com
# 9             stackoverflow.com                                        com
# 34                  youtube.com                                        com
# 40                  youtube.com                                        com
# 10            stackoverflow.com                                        com
# 39                  youtube.com                                        com
# 1                    google.com                                        com
# 8             stackoverflow.com                                        com
# 24                   google.com                                        com
# 35                  youtube.com                                        com
# 5                   twitter.com                                        com
# 31                  youtube.com                                        com
# 2                    google.com                                        com
# 11            stackoverflow.com                                        com
# 22                   google.com                                        com
# 49                   google.com                                        com
# 28                   google.com                                        com
# 26                   google.com                                        com
# 20                   google.com                                        com
# 17                    baidu.com                                        com
# 48                     ebay.com                                        com
# 45                   amazon.com                                        com
# 7                     yahoo.com                                        com
# 0                    google.com                                        com
# 36                  youtube.com                                        com
# 19                     ebay.com                                        com
# 33                  youtube.com                                        com
# 32                  youtube.com                                        com
# 12            stackoverflow.com                                        com
#
#    search_provider_alexa_rank search_provider_category  \
# 30                          2            media-sharing
# 23                          1            search-engine
# 21                          1            search-engine
# 44                          1            search-engine
# 13                         43      question-and-answer
# 3                          31               e-commerce
# 38                          2            media-sharing
# 46                         31               e-commerce
# 41                          2            media-sharing
# 6                          26             social-media
# 29                         13            search-engine
# 47                         10               e-commerce
# 37                          2            media-sharing
# 15                         10               e-commerce
# 18                         25            search-engine
# 43                          1            search-engine
# 42                          2            media-sharing
# 27                          1            search-engine
# 4                          10               e-commerce
# 16                         10               e-commerce
# 25                          1            search-engine
# 14                         33               e-commerce
# 9                          43      question-and-answer
# 34                          2            media-sharing
# 40                          2            media-sharing
# 10                         43      question-and-answer
# 39                          2            media-sharing
# 1                           1            search-engine
# 8                          43      question-and-answer
# 24                          1            search-engine
# 35                          2            media-sharing
# 5                          26             social-media
# 31                          2            media-sharing
# 2                           1            search-engine
# 11                         43      question-and-answer
# 22                          1            search-engine
# 49                          1            search-engine
# 28                          1            search-engine
# 26                          1            search-engine
# 20                          1            search-engine
# 17                          3            search-engine
# 48                         31               e-commerce
# 45                         10               e-commerce
# 7                           9               web-portal
# 0                           1            search-engine
# 36                          2            media-sharing
# 19                         31               e-commerce
# 33                          2            media-sharing
# 32                          2            media-sharing
# 12                         43      question-and-answer
#
#     serp_domain_public_suffix         serp_domain serp_year serp_month
# 30                        com     www.youtube.com      2019         10
# 23                        com      www.google.com      2021          4
# 21                        com      www.google.com      2021          1
# 44                         dk       www.google.dk      2021          9
# 13                        com   stackoverflow.com      2020          5
# 3                      com.au     www.ebay.com.au      2020          1
# 38                        com     www.youtube.com      2020          1
# 46                         fr         www.ebay.fr      2021         10
# 41                        com     www.youtube.com      2020          1
# 6                         com  mobile.twitter.com      2014          9
# 29                        com          www.so.com      2020          3
# 47                         in       www.amazon.in      2022          9
# 37                        com     www.youtube.com      2019          9
# 15                        com      www.amazon.com      2021          1
# 18                        com        www.bing.com      2022          6
# 43                         de       www.google.de      2018          2
# 42                        com     www.youtube.com      2020          2
# 27                        com      www.google.com      2022          5
# 4                      com.br   www.amazon.com.br      2021         10
# 16                        com      www.amazon.com      2022          2
# 25                        com      www.google.com      2022          2
# 14                        com  www.aliexpress.com      2015          6
# 9                         com   stackoverflow.com      2017         10
# 34                        com     www.youtube.com      2019          6
# 40                        com     www.youtube.com      2020          1
# 10                        com   stackoverflow.com      2019         11
# 39                        com     www.youtube.com      2020          1
# 1                       co.jp    www.google.co.jp      2022          8
# 8                         com   stackoverflow.com      2014          9
# 24                        com      www.google.com      2021          9
# 35                        com     www.youtube.com      2019          7
# 5                         com  mobile.twitter.com      2012          6
# 31                        com     www.youtube.com      2019         11
# 2                       co.uk    www.google.co.uk      2021          4
# 11                        com   stackoverflow.com      2019         12
# 22                        com      www.google.com      2021          2
# 49                         lv       www.google.lv      2021          4
# 28                        com      www.google.com      2022          9
# 26                        com      www.google.com      2022          3
# 20                        com      www.google.com      2020         12
# 17                        com       www.baidu.com      2022          8
# 48                         it         www.ebay.it      2022          8
# 45                         es       www.amazon.es      2022          3
# 7                         com    search.yahoo.com      2022          7
# 0                       co.in    www.google.co.in      2021          6
# 36                        com     www.youtube.com      2019          7
# 19                        com        www.ebay.com      2021          2
# 33                        com     www.youtube.com      2019          6
# 32                        com     www.youtube.com      2019         11
# 12                        com   stackoverflow.com      2019          3
#
# [50 rows x 32 columns]
